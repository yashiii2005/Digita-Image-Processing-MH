# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read image in grayscale
img = cv2.imread(r'C:\Users\LENOVO\OneDrive\Desktop\miranda\img.png', 0)

if img is None:
    print("Error: Image not found. Please check the file name/path.")
else:
    plt.imshow(img, cmap='gray')
    plt.title("Original Image")
    plt.axis("off")

# %%
# Kernel / Structuring Element (3x3 matrix of ones)
kernel = np.ones((5,5), np.uint8)
